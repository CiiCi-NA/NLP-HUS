# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import Tokenizer, CountVectorizer

# %% [markdown]
# # Khởi tạo SparkSession

# %%
spark = SparkSession.builder.appName("TestVectorization").getOrCreate()

# %% [markdown]
# # Đọc json lines(Mỗi dòng là 1 document)

# %%
df = spark.read.json("data/datatest.json")

print("Số lượng documents:", df.count())
df.show(5, truncate=80)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = spark.read.json("data/datatest.json")
#       3 print("Số lượng documents:", df.count())
#       4 df.show(5, truncate=80)
#
# AttributeError: 'function' object has no attribute 'read'
